# %%
import pandas as pd

# %%
df = pd.read_csv("epigenomic_dataset/epigenomes.csv")

# %%
for index, g in df.groupby(["cell_line", "target"]):
    if len(g)>2:
        display(g)
# Out:
#        accession assembly biological_replicates file_format   file_size  \
# 26   ENCFF486PYA     hg19                [1, 2]      bigWig  1117677730
# 105  ENCFF377GCQ     hg19                [1, 2]      bigWig  1852683009
# 798  ENCFF422WMJ     hg19                [1, 2]      bigWig  1838524283
#
#                   output_type    status  \
# 26   fold change over control  archived
# 105  fold change over control  archived
# 798  fold change over control  released
#
#                                                    url organism cell_line  \
# 26   https://encode-public.s3.amazonaws.com/2015/10...    human   GM12878
# 105  https://encode-public.s3.amazonaws.com/2015/11...    human   GM12878
# 798  https://encode-public.s3.amazonaws.com/2018/02...    human   GM12878
#
#     target
# 26    ETV6
# 105   ETV6
# 798   ETV6
#        accession assembly biological_replicates file_format   file_size  \
# 159  ENCFF638KYE     hg19                [1, 2]      bigWig  2171017618
# ...
